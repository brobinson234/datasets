# %%
# This project will focus on Netflix's stock price over the 2017 calendar year. The goal is to apply visualiation to answer the following questions: the distribution of the stock prices for the past year; Netflix's earnings and revenue in the last four quarters; The actual vs. estimated earnings per share for the four quarters in 2017; A comparison of the Netflix Stock price vs the Dow Jones Industrial Average price in 2017

import pandas as pd 
from matplotlib import pyplot as plt
import seaborn as sns

# %%
nflx_df = pd.read_csv('NFLX_daily_by_quarter.csv')
print(nflx_df.head())

dji_df = pd.read_csv('dji.csv')
print(dji_df.head())

nflx_start_each_month_df = pd.read_csv('nflx.csv')
print(nflx_start_each_month_df)
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2017-01-03  124.959999  128.190002  124.309998  127.489998  127.489998
# 1  2017-01-04  127.489998  130.169998  126.550003  129.410004  129.410004
# 2  2017-01-05  129.220001  132.750000  128.899994  131.809998  131.809998
# 3  2017-01-06  132.080002  133.880005  129.809998  131.070007  131.070007
# 4  2017-01-09  131.479996  131.990005  129.889999  130.949997  130.949997
#
#      Volume Quarter
# 0   9437900      Q1
# 1   7843600      Q1
# 2  10185500      Q1
# 3  10657900      Q1
# 4   5766900      Q1
#          Date          Open          High           Low         Close  \
# 0  2017-01-01  19872.859375  20125.580078  19677.939453  19864.089844
# 1  2017-02-01  19923.810547  20851.330078  19831.089844  20812.240234
# 2  2017-03-01  20957.289063  21169.109375  20412.800781  20663.220703
# 3  2017-04-01  20665.169922  21070.900391  20379.550781  20940.509766
# ...

# %%
nflx_df = nflx_df.rename(columns={'Adj Close': 'Price'})
print(nflx_df.head(2))

dji_df = dji_df.rename(columns={'Adj Close': 'Price'})
print(dji_df.head(2))
# Out:
#          Date        Open        High         Low       Close       Price  \
# 0  2017-01-03  124.959999  128.190002  124.309998  127.489998  127.489998
# 1  2017-01-04  127.489998  130.169998  126.550003  129.410004  129.410004
#
#     Volume Quarter
# 0  9437900      Q1
# 1  7843600      Q1
#          Date          Open          High           Low         Close  \
# 0  2017-01-01  19872.859375  20125.580078  19677.939453  19864.089844
# 1  2017-02-01  19923.810547  20851.330078  19831.089844  20812.240234
#
#           Price      Volume
# 0  19864.089844  6482450000
# 1  20812.240234  6185580000

# %%
f, ax = plt.subplots(figsize=(15, 10))
ax = sns.lineplot(data=nflx_df, x='Date', y='Price')


#import matplotlib.ticker as mtick
#fmt = '${x:,.0f}'
#tick = mtick.StrMethodFormatter(fmt)
#ax.yaxis.set_major_formatter(tick)
plt.show()

# %%
f, ax = plt.subplots(figsize=(15, 10))
ax = sns.lineplot(data=dji_df, x='Date', y='Price')
plt.show()

# %%
ax = sns.violinplot(data=nflx_df, x='Quarter', y='Price')

# %%
dji_df['Quarter'] = dji_df['Date'] == '2017-01-01'
print(dji_df.head())
# Out:
#          Date          Open          High           Low         Close  \
# 0  2017-01-01  19872.859375  20125.580078  19677.939453  19864.089844
# 1  2017-02-01  19923.810547  20851.330078  19831.089844  20812.240234
# 2  2017-03-01  20957.289063  21169.109375  20412.800781  20663.220703
# 3  2017-04-01  20665.169922  21070.900391  20379.550781  20940.509766
# 4  2017-05-01  20962.730469  21112.320313  20553.449219  21008.650391
#
#           Price      Volume  Quarter
# 0  19864.089844  6482450000     True
# 1  20812.240234  6185580000    False
# 2  20663.220703  6941970000    False
# 3  20940.509766  5392630000    False
# 4  21008.650391  6613570000    False

# %%
#ax = sns.violinplot(data=dji_df, x='Quarter', y='Price')

# %%
ax = sns.boxenplot(data=nflx_df, x='Quarter', y='Price')

# %%
ax = sns.scatterplot(data=nflx_df, y='Price', x='Volume', color='red')

# %%
ax = sns.scatterplot(data=dji_df, y='Price', x='Volume', color='red')
